# %% [markdown]
# <div style="text-align: center;">
#   <img src="https://github.com/Hack-io-Data/Imagenes/blob/main/01-LogosHackio/logo_naranja@4x.png?raw=true" alt="esquema" />
# </div>

# %% [markdown]
# # Laboratorio Agrupamiento de Datos
#
# En este laboratorio usaremos el DataFrame creado en la lección anterior resultado de la unión de los conjuntos de datos compartidos contigo.
#
# **Instrucciones:**
#
# 1. Lee cuidadosamente el enunciado de cada ejercicio.
#
# 2. Implementa la solución en la celda de código proporcionada.
#
# 3. Devuelve los resultados siempre en formato de DataFrame

# %% [markdown]
# #### Ejercicio 1: ¿Cuántos títulos hay por cada tipo de contenido ('Movie' o 'TV Show')?

# %%
import pandas as pd

df_merged = pd.read_csv("datos/df_merged.csv")

df_merged.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df_merged.groupby(['type']).count()['title'].reset_index()
# Out:
#       type  title
# 0    Movie   6131
# 1  TV Show   2676

# %% [markdown]
# #### Ejercicio 2: ¿Cuál es el promedio de puntuación de las películas agrupadas por clasificación de audiencia ('rating')? Interpreta los resultados, ¿hay algo que te llame la atención? Explica por qué.

# %%
df_merged.groupby(['rating']).mean(numeric_only=True).sort_values(by="IMDB Score", ascending=False)
# Out:
#           IMDB Score  release_year
# rating
# PG          6.800000   2008.428571
# TV-Y        6.780000   2017.159609
# G           6.500000   1997.804878
# R           6.495745   2010.471840
# PG-13       6.386957   2009.314286
# TV-PG       6.308772   2013.529548
# TV-Y7       6.240000   2015.508982
# TV-14       6.177660   2013.655556
# TV-G        6.156250   2015.745455
# TV-MA       6.097638   2016.661678
# 66 min           NaN   2015.000000
# 74 min           NaN   2017.000000
# 84 min           NaN   2010.000000
# NC-17            NaN   2015.000000
# NR               NaN   2010.912500
# TV-Y7-FV         NaN   2014.833333
# UR               NaN   1999.333333

# %% [markdown]
# ### Las que me llaman la atencion son las que hay de tipo object.

# %% [markdown]
# #### Ejercicio 3: ¿Cuántos títulos hay por cada país? Ordena los resultados de mayor a menor

# %%
df_merged.groupby(['country']).count().reset_index().sort_values(by='title', ascending=False)
# Out:
#                  country  IMDB Score  Language  show_id  type  title  \
# 603        United States         274       274     2818  2818   2818
# 251                India          35        35      972   972    972
# 506       United Kingdom          13        13      419   419    419
# 319                Japan           4         4      245   245    245
# 435          South Korea           6         6      199   199    199
# ..                   ...         ...       ...      ...   ...    ...
# 743            Venezuela           0         0        1     1      1
# 744  Venezuela, Colombia           0         0        1     1      1
# 128               Cyprus           0         0        1     1      1
# 746         West Germany           0         0        1     1      1
# 747             Zimbabwe           0         0        1     1      1
#
#      director  cast  date_added  release_year  rating  duration  listed_in  \
# 603      2048  2488        2812          2818    2818      1305       2818
# 251       890   940         972           972     972       711        972
# 506       212   351         418           419     419       155        419
# 319        85   240         244           245     244        81        245
# 435        49   196         199           199     199        45        199
# ..        ...   ...         ...           ...     ...       ...        ...
# 743         1     1           1             1       1         1          1
# 744         1     0           1             1       1         1          1
# 128         0     1           1             1       1         0          1
# 746         1     0           1             1       1         1          1
# 747         1     1           1             1       1         0          1
#
#      description
# 603         2818
# 251          972
# 506          419
# 319          245
# 435          199
# ..           ...
# 743            1
# 744            1
# 128            1
# 746            1
# 747            1
#
# [748 rows x 14 columns]

# %% [markdown]
# #### Ejercicio 4: ¿Cuál es la calificación promedio en IMDb de los títulos agrupados por tipo ('Movie' o 'TV Show')?

# %%
df_merged.groupby(['type']).mean(numeric_only=True)
# Out:
#          IMDB Score  release_year
# type
# Movie      6.210916   2013.121514
# TV Show         NaN   2016.605755

# %% [markdown]
# #### Ejercicio 5: ¿Cuántos títulos se añadieron a Netflix cada año? Para resolver este ejercicio tendrás uqe convertir la columna `date_added` a formato fecha usando el método `pd.to_datetime`. [Aquí](https://pandas.pydata.org/docs/reference/api/pandas.to_datetime.html) tienes la documentación, leeala con detenimiento antes de usar el método.

# %%
df_merged['date_added'] = pd.to_datetime(df_merged['date_added'].str.strip(), format='%B %d, %Y')
#df_merged.groupby('release_year').count()

df_merged.groupby('release_year')['date_added'].count().reset_index().sort_values(by='date_added', ascending=False)
# Out:
#     release_year  date_added
# 70          2018        1146
# 69          2017        1032
# 71          2019        1030
# 72          2020         953
# 68          2016         901
# ..           ...         ...
# 0           1925           1
# 6           1947           1
# 11          1959           1
# 18          1966           1
# 13          1961           1
#
# [74 rows x 2 columns]

# %% [markdown]
# #### Ejercicio 6: ¿Cuál es el país con más títulos lanzados en el año 2020? Para resolver este ejercicio después del gropuby os puede resultar interesante el método [`idxmax`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.idxmax.html)

# %%
condicion = df_merged['release_year'] == 2020
df_merged[condicion].groupby(['country']).count().sort_values(by='title', ascending=False)
# Out:
#                                       IMDB Score  Language  show_id  type  \
# country
# United States                                 74        74      336   336
# India                                         17        17       75    75
# United Kingdom                                 5         5       44    44
# South Korea                                    3         3       28    28
# Canada                                         3         3       26    26
# ...                                          ...       ...      ...   ...
# United States, Thailand                        0         0        1     1
# United States, United Kingdom                  1         1        1     1
# United States, United Kingdom, India           1         1        1     1
# Uruguay                                        0         0        1     1
# Vietnam                                        0         0        1     1
#
#                                       title  director  cast  date_added  \
# country
# United States                           336       177   276         336
# India                                    75        61    69          75
# United Kingdom                           44        20    35          44
# South Korea                              28         5    28          28
# Canada                                   26        15    23          26
# ...                                     ...       ...   ...         ...
# United States, Thailand                   1         1     1           1
# United States, United Kingdom             1         1     1           1
# United States, United Kingdom, India      1         1     1           1
# Uruguay                                   1         1     1           1
# Vietnam                                   1         1     1           1
#
#                                       release_year  rating  duration  \
# country
# United States                                  336     336       133
# India                                           75      75        45
# United Kingdom                                  44      44        18
# South Korea                                     28      28         3
# Canada                                          26      26        15
# ...                                            ...     ...       ...
# United States, Thailand                          1       1         0
# United States, United Kingdom                    1       1         1
# United States, United Kingdom, India             1       1         1
# Uruguay                                          1       1         0
# Vietnam                                          1       1         0
#
#                                       listed_in  description
# country
# United States                               336          336
# India                                        75           75
# United Kingdom                               44           44
# South Korea                                  28           28
# Canada                                       26           26
# ...                                         ...          ...
# United States, Thailand                       1            1
# United States, United Kingdom                 1            1
# United States, United Kingdom, India          1            1
# Uruguay                                       1            1
# Vietnam                                       1            1
#
# [107 rows x 13 columns]

# %% [markdown]
# #### Ejercicio 7:¿Cuál es el promedio de puntuación en IMDb de los títulos agrupados por país?

# %%
df_merged.groupby(['country'])['IMDB Score'].mean().sort_values(ascending=False)
# Out:
# country
# United Kingdom, Ukraine, United States    8.4
# Spain, United Kingdom                     8.2
# United States, United Kingdom             8.2
# United States, United Kingdom, India      7.8
# Australia, United States                  7.6
#                                          ...
# Venezuela                                 NaN
# Venezuela, Colombia                       NaN
# Vietnam                                   NaN
# West Germany                              NaN
# Zimbabwe                                  NaN
# Name: IMDB Score, Length: 748, dtype: float64

# %% [markdown]
# #### Ejercicio 8: ¿Cuántos títulos fueron lanzados en cada año agrupados por tipo ('Movie' o 'TV Show')?

# %%
df_merged.groupby(['type', 'release_year'])['title'].count().reset_index().sort_values(by='title',ascending=False)
# Out:
#        type  release_year  title
# 68    Movie          2017    767
# 69    Movie          2018    767
# 67    Movie          2016    658
# 70    Movie          2019    633
# 71    Movie          2020    517
# ..      ...           ...    ...
# 75  TV Show          1946      1
# 80  TV Show          1977      1
# 79  TV Show          1974      1
# 77  TV Show          1967      1
# 88  TV Show          1991      1
#
# [119 rows x 3 columns]

# %% [markdown]
# #### Ejercicio 9: ¿Cuál es el país con la mayor cantidad de títulos de clasificación 'TV-MA'?

# %%
df_9 = df_merged[df_merged['rating'] == 'TV-MA']
df_9.groupby('country')['rating'].count().reset_index().sort_values(by='rating', ascending=False)
# Out:
#                                             country  rating
# 274                                   United States     928
# 101                                           India     248
# 241                                  United Kingdom     177
# 205                                           Spain     119
# 133                                           Japan      87
# ..                                              ...     ...
# 253  United Kingdom, France, United States, Belgium       1
# 254                         United Kingdom, Germany       1
# 255  United Kingdom, Germany, United States, France       1
# 256                           United Kingdom, India       1
# 257                         United Kingdom, Ireland       1
#
# [314 rows x 2 columns]

# %% [markdown]
# #### Ejercicio 10. ¿Cuál es el promedio de duración de las películas agrupadas por país?

# %%
df_merged['duration'] = df_merged['duration'].str.replace(' min','')

df_merged.groupby('country')['duration'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\JLFA\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File c:\Users\JLFA\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File c:\Users\JLFA\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
#
# File c:\Users\JLFA\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:2454, in GroupBy.mean.<locals>.<lambda>(x)
#    2451 else:
#    2452     result = self._cython_agg_general(
#    2453         "mean",
# -> 2454         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455         numeric_only=numeric_only,
#    2456     )
#    2457     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Users\JLFA\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:6549, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6541 @doc(make_doc("mean", ndim=1))
#    6542 def mean(
#    6543     self,
#    (...)
#    6547     **kwargs,
#    6548 ):
# -> 6549     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File c:\Users\JLFA\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
#   12418     **kwargs,
#   12419 ) -> Series | float:
# > 12420     return self._stat_function(
#   12421         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422     )
#
# File c:\Users\JLFA\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:12377, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12375 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12377 return self._reduce(
#   12378     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12379 )
#
# File c:\Users\JLFA\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:6457, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6453     raise TypeError(
#    6454         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6455         "with non-numeric dtypes."
#    6456     )
# -> 6457 return op(delegate, skipna=skipna, **kwds)
#
# File c:\Users\JLFA\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File c:\Users\JLFA\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#
# File c:\Users\JLFA\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:719, in nanmean(values, axis, skipna, mask)
#     718 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 719 the_sum = values.sum(axis, dtype=dtype_sum)
#     720 the_sum = _ensure_numeric(the_sum)
#
# File c:\Users\JLFA\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\_core\_methods.py:53, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      51 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      52          initial=_NoValue, where=True):
# ---> 53     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# TypeError: can only concatenate str (not "int") to str
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[312], line 3
#       1 df_merged['duration'] = df_merged['duration'].str.replace(' min','')
# ----> 3 df_merged.groupby('country')['duration'].mean()
#
# File c:\Users\JLFA\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:2452, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2445     return self._numba_agg_general(
#    2446         grouped_mean,
#    2447         executor.float_dtype_mapping,
#    2448         engine_kwargs,
#    2449         min_periods=0,
#    2450     )
#    2451 else:
# -> 2452     result = self._cython_agg_general(
#    2453         "mean",
#    2454         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455         numeric_only=numeric_only,
#    2456     )
#    2457     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Users\JLFA\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1998, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1995     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996     return result
# -> 1998 new_mgr = data.grouped_reduce(array_func)
#    1999 res = self._wrap_agged_manager(new_mgr)
#    2000 if how in ["idxmin", "idxmax"]:
#
# File c:\Users\JLFA\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\base.py:367, in SingleDataManager.grouped_reduce(self, func)
#     365 def grouped_reduce(self, func):
#     366     arr = self.array
# --> 367     res = func(arr)
#     368     index = default_index(len(res))
#     370     mgr = type(self).from_array(res, index)
#
# File c:\Users\JLFA\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1995, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1992     return result
#    1994 assert alt is not None
# -> 1995 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996 return result
#
# File c:\Users\JLFA\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1946, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1944     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1945     # preserve the kind of exception that raised
# -> 1946     raise type(err)(msg) from err
#    1948 if ser.dtype == object:
#    1949     res_values = res_values.astype(object, copy=False)
#
# TypeError: agg function failed [how->mean,dtype->object]

# %%
df_merged.head()
# Out:
#    IMDB Score          Language show_id   type            title  \
# 0         2.5  English/Japanese   s3624  Movie  Enter the Anime
# 1         2.6           Spanish   s2105  Movie      Dark Forces
# 2         2.6           Italian   s3095  Movie          The App
# 3         3.2           English   s5074  Movie   The Open House
# 4         3.4             Hindi   s1778  Movie      Kaali Khuhi
#
#                     director  \
# 0              Alex Burunova
# 1          Bernardo Arellano
# 2               Elisa Fuksas
# 3  Matt Angel, Suzanne Coote
# 4            Terrie Samundra
#
#                                                 cast                country  \
# 0  Kozo Morishita, Yoko Takahashi, Shinji Aramaki...   United States, Japan
# 1  Tenoch Huerta, Eréndira Ibarra, Dale Carley, A...                 Mexico
# 2  Vincenzo Crea, Jessica Cressy, Greta Scarano, ...                  Italy
# 3  Dylan Minnette, Piercey Dalton, Patricia Bethu...  Canada, United States
# 4  Shabana Azmi, Leela Samson, Sanjeeda Sheikh, S...                  India
#
#   date_added  release_year rating duration  \
# 0 2019-08-05          2019  TV-MA       59
# 1 2020-08-21          2020  TV-MA       81
# 2 2019-12-26          2019  TV-MA       79
# 3 2018-01-19          2018  TV-MA      NaN
# 4 2020-10-30          2020  TV-14      NaN
#
#                                            listed_in  \
# 0                Documentaries, International Movies
# 1  Horror Movies, Independent Movies, Internation...
# 2   Dramas, Independent Movies, International Movies
# 3                           Horror Movies, Thrillers
# 4                Horror Movies, International Movies
#
#                                          description
# 0  What is anime? Through deep-dives with notable...
# 1  In search of his sister, a renegade criminal s...
# 2  While in Rome to shoot his first movie, actor ...
# 3  Following a tragedy, a mother and her teen son...
# 4  When a restless spirit curses a village that h...

# %% [markdown]
# #### Ejercicio 11: ¿Cuál es el número total de títulos por país y clasificación de audiencia ('rating')?

# %%
df_merged.groupby(['country', 'rating'])['title'].count().reset_index().sort_values(by='title',ascending=False)
# Out:
#                                        country rating  title
# 945                              United States  TV-MA    928
# 390                                      India  TV-14    550
# 942                              United States      R    440
# 943                              United States  TV-14    406
# 941                              United States  PG-13    289
# ...                                        ...    ...    ...
# 1138             United States, United Kingdom   TV-Y      1
# 1140  United States, United Kingdom, Australia  TV-Y7      1
# 1141     United States, United Kingdom, Canada     PG      1
# 1142     United States, United Kingdom, Canada      R      1
# 1127                United States, Switzerland      R      1
#
# [1175 rows x 3 columns]

# %% [markdown]
# #### Ejercicio 12: ¿Cuántos títulos fueron lanzados antes del año 2000 agrupados por país?

# %%
df_filtrado = df_merged[df_merged['release_year'] < 2000]
df_merged.groupby(['country'])['title'].count().reset_index().sort_values(by='title', ascending=False)
# Out:
#                  country  title
# 603        United States   2818
# 251                India    972
# 506       United Kingdom    419
# 319                Japan    245
# 435          South Korea    199
# ..                   ...    ...
# 743            Venezuela      1
# 744  Venezuela, Colombia      1
# 128               Cyprus      1
# 746         West Germany      1
# 747             Zimbabwe      1
#
# [748 rows x 2 columns]

# %% [markdown]
# #### Ejercicio 13: ¿Cuál es la puntuación promedio en IMDb de los títulos lanzados en 2021 agrupados por país?

# %%
df_filtrado = df_merged[df_merged['release_year'] == 2021]
df_filtrado.groupby(['country'])[['IMDB Score']].mean().sort_values(by='IMDB Score', ascending=False)
# Out:
#                                IMDB Score
# country
# Belgium, Netherlands                  7.1
# United Kingdom                        7.1
# India, United States                  7.1
# France, United States                 6.5
# Spain                                 6.4
# ...                                   ...
# United States, Mexico                 NaN
# United States, Singapore              NaN
# United States, United Kingdom         NaN
# Uruguay, Germany                      NaN
# Vietnam                               NaN
#
# [75 rows x 1 columns]

# %% [markdown]
# #### Ejercicio 14: ¿Cuántos títulos fueron dirigidos por cada director? Ordena los resultados de mayor a menor

# %%
df_merged.groupby(['director'])[['title']].count().sort_values(by='title', ascending=False)
# Out:
#                         title
# director
# Rajiv Chilaka              19
# Raúl Campos, Jan Suter     18
# Marcus Raboy               16
# Suhas Kadav                16
# Jay Karas                  14
# ...                       ...
# Çagan Irmak                 1
# Ísold Uggadóttir            1
# Óskar Thór Axelsson         1
# Braden R. Duemmler          1
# Zachary Heinzerling         1
#
# [4528 rows x 1 columns]

# %% [markdown]
# #### Ejercicio 15: ¿Cuál es el lenguaje más frecuente en los títulos lanzados en los últimos 5 años agrupado por país?

# %%
df_titulos_cinco_anios = df_merged[df_merged['release_year'].between(2019,2024, inclusive='both')]

df_titulos_cinco_anios.groupby(['country','Language'])['title'].count().reset_index().sort_values(by='title',ascending=False)
# Out:
#                                    country          Language  title
# 56                           United States           English    142
# 19                                   India             Hindi     25
# 11                                  France            French     11
# 23                                   Italy           Italian     11
# 43                                   Spain           Spanish      9
# ..                                     ...               ...    ...
# 66                    United States, Japan  English/Japanese      1
# 68                   United States, Mexico           Spanish      1
# 69           United States, United Kingdom           English      1
# 70  United States, United Kingdom, Germany           English      1
# 71    United States, United Kingdom, India           English      1
#
# [72 rows x 3 columns]

# %%
df_merged.head()
# Out:
#    IMDB Score          Language show_id   type            title  \
# 0         2.5  English/Japanese   s3624  Movie  Enter the Anime
# 1         2.6           Spanish   s2105  Movie      Dark Forces
# 2         2.6           Italian   s3095  Movie          The App
# 3         3.2           English   s5074  Movie   The Open House
# 4         3.4             Hindi   s1778  Movie      Kaali Khuhi
#
#                     director  \
# 0              Alex Burunova
# 1          Bernardo Arellano
# 2               Elisa Fuksas
# 3  Matt Angel, Suzanne Coote
# 4            Terrie Samundra
#
#                                                 cast                country  \
# 0  Kozo Morishita, Yoko Takahashi, Shinji Aramaki...   United States, Japan
# 1  Tenoch Huerta, Eréndira Ibarra, Dale Carley, A...                 Mexico
# 2  Vincenzo Crea, Jessica Cressy, Greta Scarano, ...                  Italy
# 3  Dylan Minnette, Piercey Dalton, Patricia Bethu...  Canada, United States
# 4  Shabana Azmi, Leela Samson, Sanjeeda Sheikh, S...                  India
#
#   date_added  release_year rating duration  \
# 0 2019-08-05          2019  TV-MA       59
# 1 2020-08-21          2020  TV-MA       81
# 2 2019-12-26          2019  TV-MA       79
# 3 2018-01-19          2018  TV-MA      NaN
# 4 2020-10-30          2020  TV-14      NaN
#
#                                            listed_in  \
# 0                Documentaries, International Movies
# 1  Horror Movies, Independent Movies, Internation...
# 2   Dramas, Independent Movies, International Movies
# 3                           Horror Movies, Thrillers
# 4                Horror Movies, International Movies
#
#                                          description
# 0  What is anime? Through deep-dives with notable...
# 1  In search of his sister, a renegade criminal s...
# 2  While in Rome to shoot his first movie, actor ...
# 3  Following a tragedy, a mother and her teen son...
# 4  When a restless spirit curses a village that h...
